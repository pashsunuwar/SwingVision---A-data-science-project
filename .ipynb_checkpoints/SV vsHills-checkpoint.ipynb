# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('vsHills.csv')

# %%
df.head(10)
# Out:
#      Player  Shot             Type    Stroke     Spin  Speed (MPH)  Point  \
# 0    Pash S     0             none      Feed     Flat    19.052607      1
# 1  Opponent     1      first_serve     Serve    Slice    59.798580      1
# 2    Pash S     2     first_return  Forehand     Flat    35.366428      1
# 3  Opponent     3   serve_plus_one  Forehand  Topspin    45.510433      1
# 4    Pash S     4  return_plus_one  Forehand  Topspin    44.407497      1
# 5  Opponent     5          in_play  Forehand  Topspin    53.217064      1
# 6    Pash S     6          in_play  Forehand  Topspin    44.265747      1
# 7  Opponent     7          in_play  Forehand  Topspin    65.717102      1
# 8    Pash S     8          in_play  Backhand    Slice    37.185963      1
# 9    Pash S     9             none      Feed     Flat    20.346201      1
#
#    Game  Set Bounce Depth  ...     Hit Zone Hit Side   Hit (x)    Hit (y)  \
# 0     1    1        short  ...        deuce     near  2.552158   2.042202
# ...

# %%
df.tail(7)
# Out:
#        Player  Shot             Type    Stroke     Spin  Speed (MPH)  Point  \
# 518    Pash S     1      first_serve     Serve    Slice    79.459663     88
# 519  Opponent     2     first_return  Forehand    Slice    32.825764     88
# 520    Pash S     3   serve_plus_one  Forehand     Flat    37.975246     88
# 521  Opponent     4  return_plus_one  Forehand     Flat    44.073074     88
# 522    Pash S     5          in_play  Backhand  Topspin    31.150671     88
# 523  Opponent     6          in_play  Backhand    Slice    29.532509     88
# 524    Pash S     7          in_play  Backhand  Topspin    38.584530     88
#
#      Game  Set Bounce Depth  ... Hit Zone Hit Side   Hit (x)    Hit (y)  \
# 518    12    2        short  ...    deuce     near  0.883948   0.494053
# 519    12    2         deep  ...    deuce      far -3.032067  23.627634
# 520    12    2        short  ...       ad     near -0.210810  -1.911277
# ...

# %%
df.sample()
# Out:
#        Player  Shot            Type    Stroke     Spin  Speed (MPH)  Point  \
# 191  Opponent     3  serve_plus_one  Forehand  Topspin    57.234837     32
#
#      Game  Set Bounce Depth  ... Hit Zone Hit Side   Hit (x)    Hit (y)  \
# 191     5    1         deep  ...    deuce      far -2.651342  26.306627
#
#       Hit (z)      Direction Result  Favorited  Start Time   Video Time
# 191  0.639589  down the line    Out      False    19:01:00  1184.170044
#
# [1 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# Player          0
# Shot            0
# Type            0
# Stroke          0
# Spin            0
# Speed (MPH)     0
# Point           0
# Game            0
# Set             0
# Bounce Depth    0
# Bounce Zone     0
# Bounce Side     0
# Bounce (x)      0
# Bounce (y)      0
# Hit Depth       0
# Hit Zone        0
# Hit Side        0
# Hit (x)         0
# Hit (y)         0
# Hit (z)         0
# Direction       0
# Result          0
# Favorited       0
# Start Time      0
# Video Time      0
# dtype: int64

# %%
df.describe()
# Out:
#              Shot  Speed (MPH)       Point        Game         Set  \
# count  525.000000   525.000000  525.000000  525.000000  525.000000
# mean     3.198095    44.065007   42.045714    5.811429    1.144762
# std      2.632518    14.841707   24.827839    2.862075    0.352196
# min      0.000000    10.748139    1.000000    1.000000    1.000000
# 25%      1.000000    34.983292   23.000000    4.000000    1.000000
# 50%      2.000000    44.178173   41.000000    6.000000    1.000000
# 75%      5.000000    52.125622   61.000000    7.000000    1.000000
# max     14.000000   112.583580   88.000000   12.000000    2.000000
#
#        Bounce (x)  Bounce (y)     Hit (x)     Hit (y)     Hit (z)   Video Time
# count  525.000000  525.000000  525.000000  525.000000  525.000000   525.000000
# mean    -0.126136   11.976776   -0.155977   12.121947    1.451305  1593.007733
# std      2.248343    7.078709    2.325492   11.811188    0.783673   914.519325
# ...

# %%
## Who hit the fastest serve? What was the speed? 

#df[['Player', 'Stroke', 'Speed (MPH)']]

serve_df = df[df['Stroke']=='Serve']

serve_df.sample()
# Out:
#      Player  Shot         Type Stroke  Spin  Speed (MPH)  Point  Game  Set  \
# 271  Pash S     1  first_serve  Serve  Flat    73.482079     43     6    1
#
#     Bounce Depth  ... Hit Zone Hit Side   Hit (x)    Hit (y)   Hit (z)  \
# 271         deep  ...       ad      far  1.194306  24.539766  2.636913
#
#     Direction Result  Favorited  Start Time   Video Time
# 271  out wide    Out      False    19:08:41  1644.859985
#
# [1 rows x 25 columns]

# %%
df.loc[0:9,:]
# Out:
#      Player  Shot             Type    Stroke     Spin  Speed (MPH)  Point  \
# 0    Pash S     0             none      Feed     Flat    19.052607      1
# 1  Opponent     1      first_serve     Serve    Slice    59.798580      1
# 2    Pash S     2     first_return  Forehand     Flat    35.366428      1
# 3  Opponent     3   serve_plus_one  Forehand  Topspin    45.510433      1
# 4    Pash S     4  return_plus_one  Forehand  Topspin    44.407497      1
# 5  Opponent     5          in_play  Forehand  Topspin    53.217064      1
# 6    Pash S     6          in_play  Forehand  Topspin    44.265747      1
# 7  Opponent     7          in_play  Forehand  Topspin    65.717102      1
# 8    Pash S     8          in_play  Backhand    Slice    37.185963      1
# 9    Pash S     9             none      Feed     Flat    20.346201      1
#
#    Game  Set Bounce Depth  ...     Hit Zone Hit Side   Hit (x)    Hit (y)  \
# 0     1    1        short  ...        deuce     near  2.552158   2.042202
# ...

# %%
df[df.loc[:, 'Player']=='Pash S'].sort_values(['Speed (MPH)', 'Result'])
# Out:
#      Player  Shot         Type    Stroke     Spin  Speed (MPH)  Point  Game  \
# 69   Pash S     9         none      Feed  Topspin    12.296117     10     2
# 81   Pash S     5         none      Feed     Flat    16.906532     12     2
# 103  Pash S     1         none      Feed  Topspin    17.320551     15     3
# 495  Pash S     6      in_play  Backhand  Topspin    17.960073     82    11
# 214  Pash S     0         none      Feed     Flat    18.186579     35     5
# ..      ...   ...          ...       ...      ...          ...    ...   ...
# 118  Pash S     1  first_serve     Serve    Slice    80.219284     19     4
# 131  Pash S     1  first_serve     Serve     Flat    81.017197     23     4
# 277  Pash S     1  first_serve     Serve     Flat    85.196854     44     6
# 480  Pash S     1  first_serve     Serve     Flat    88.901161     80    10
# 417  Pash S     1  first_serve     Serve     Flat   112.583580     67     8
#
# ...

# %%
pash_df = df[df['Player'] == 'Pash S']

# %%
sorted_pash_df = Pash_df.sort_values(by=['Speed (MPH)', 'Result'], ascending=[False, True])

# %%
print(sorted_pash_df[['Player', 'Speed (MPH)', 'Result']])
# Out:
#      Player  Speed (MPH) Result
# 417  Pash S   112.583580     In
# 480  Pash S    88.901161     In
# 277  Pash S    85.196854    Out
# 131  Pash S    81.017197    Out
# 118  Pash S    80.219284     In
# ..      ...          ...    ...
# 366  Pash S    18.186579     In
# 495  Pash S    17.960073     In
# 103  Pash S    17.320551     In
# 81   Pash S    16.906532     In
# 69   Pash S    12.296117    Net
#
# [265 rows x 3 columns]

# %%
# Wow! I suck at this!
