# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("vsAT.csv")

# %%
print(df.head())
# Out:
#          Player  Shot             Type     Stroke     Spin  Speed (MPH)  \
# 0  Pash Sunuwar     1            serve      Serve    Slice    86.764526
# 1  Pash Sunuwar     1      first_serve      Serve    Slice    65.747261
# 2      Opponent     2           return   Backhand  Topspin    36.723362
# 3  Pash Sunuwar     3   serve_plus_one   Forehand     Flat    57.112728
# 4      Opponent     4  return_plus_one  FH Volley     Flat    24.633358
#
#    Point  Game  Set  Bounce Depth  ... Hit Zone Hit Side   Hit (x)    Hit (y)  \
# 0      1     0    0   service_box  ...    deuce     near  0.254643  -0.700088
# 1      2     0    0  no_mans_land  ...    deuce     near  0.244975   0.088906
# 2      2     0    0   service_box  ...    deuce      far -0.211258  24.281729
# 3      2     0    0   service_box  ...    deuce     near  3.432085   0.083583
# 4      2     0    0  no_mans_land  ...    deuce      far -0.392818  14.652544
#
# ...

# %%
# This prints basic statistics for each numeric column in the dataset, including count, mean, std (standard deviation),
# min, and max. 
# It provides a quick summary of the distribution of each numerical feature.

# %%
print(df.describe())
# Out:
#              Shot  Speed (MPH)       Point   Game    Set  Bounce (x)  \
# count  762.000000   762.000000  762.000000  762.0  762.0  762.000000
# mean     3.398950    44.719660  147.796588    0.0    0.0    0.084027
# std      2.584376    13.588792   78.816204    0.0    0.0    2.042739
# min      0.000000    13.359282    1.000000    0.0    0.0   -5.330816
# 25%      1.000000    36.448955   89.000000    0.0    0.0   -1.478363
# 50%      3.000000    42.792630  153.000000    0.0    0.0    0.304227
# 75%      5.000000    50.663187  213.000000    0.0    0.0    1.548256
# max     15.000000   130.596954  276.000000    0.0    0.0    6.342710
#
#        Bounce (y)     Hit (x)     Hit (y)     Hit (z)  Video Time
# count  762.000000  762.000000  762.000000  762.000000         0.0
# mean    11.264428   -0.067379   11.547189    1.384661         NaN
# std      6.924803    2.174313   11.959411    0.776421         NaN
# min     -1.384318   -5.549803   -3.055035    0.046151         NaN
# ...

# %%
sns.boxplot(x='Bounce Depth', y='Speed (MPH)', data=df)
plt.title('Box Plot of Bounce Depth vs Speed')
plt.show()

# %%
player_a = "Pash Sunuwar"
player_b = "Opponent"

# %%
data_me = df[df['Player'] == player_a]

# %%
data_alex = df[df['Player'] == player_b]

# %%
print(f"Data for {player_a}:")
print(data_me.head())
# Out:
# Data for Pash Sunuwar:
#          Player  Shot            Type    Stroke     Spin  Speed (MPH)  Point  \
# 0  Pash Sunuwar     1           serve     Serve    Slice    86.764526      1
# 1  Pash Sunuwar     1     first_serve     Serve    Slice    65.747261      2
# 3  Pash Sunuwar     3  serve_plus_one  Forehand     Flat    57.112728      2
# 5  Pash Sunuwar     5         in_play  Forehand     Flat    32.369194      2
# 7  Pash Sunuwar     7         in_play  Forehand  Topspin    33.574528      2
#
#    Game  Set  Bounce Depth  ... Hit Zone Hit Side   Hit (x)   Hit (y)  \
# 0     0    0   service_box  ...    deuce     near  0.254643 -0.700088
# 1     0    0  no_mans_land  ...    deuce     near  0.244975  0.088906
# 3     0    0   service_box  ...    deuce     near  3.432085  0.083583
# 5     0    0   service_box  ...    deuce     near  1.584095 -0.772071
# 7     0    0   service_box  ...    deuce     near  2.406317  2.741341
#
# ...

# %%
print(f"Data for {player_b}:")
print(data_alex.head())
# Out:
# Data for Opponent:
#       Player  Shot             Type     Stroke     Spin  Speed (MPH)  Point  \
# 2   Opponent     2           return   Backhand  Topspin    36.723362      2
# 4   Opponent     4  return_plus_one  FH Volley     Flat    24.633358      2
# 6   Opponent     6          in_play  BH Volley     Flat    19.052607      2
# 8   Opponent     8          in_play  BH Volley     Flat    23.382744      2
# 10  Opponent     2           return   Backhand     Flat    42.885979      3
#
#     Game  Set  Bounce Depth  ... Hit Zone Hit Side   Hit (x)    Hit (y)  \
# 2      0    0   service_box  ...    deuce      far -0.211258  24.281729
# 4      0    0  no_mans_land  ...    deuce      far -0.392818  14.652544
# 6      0    0   service_box  ...       ad      far  0.893184  16.407001
# 8      0    0           out  ...       ad      far  1.767053  17.960909
# 10     0    0  no_mans_land  ...       ad      far  2.358867  23.924463
#
# ...

# %%
sns.violinplot(x='Stroke', y='Speed (MPH)', hue = 'Result', data=data_me)
plt.title('Box Plot of Bounce Depth vs Speed')
plt.show()

# %%
sns.pairplot(data=data_me, hue="Speed (MPH)");
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
